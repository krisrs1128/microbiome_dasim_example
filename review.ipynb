# %%
if(!requireNamespace("BiocManager", quietly = TRUE)){
   install.packages("BiocManager")
}
BiocManager::install("microbiomeDASim")
# Out:
#   There is a binary version available but the source version is later:
#             binary source needs_compilation
# BiocManager 1.30.7 1.30.9             FALSE
# installing the source package ‘BiocManager’
#
# Bioconductor version 3.10 (BiocManager 1.30.9), R 3.6.1 (2019-07-05)
# Installing package(s) 'BiocVersion', 'microbiomeDASim'
# also installing the dependencies ‘magrittr’, ‘stringi’, ‘colorspace’, ‘zoo’, ‘plyr’, ‘stringr’, ‘labeling’, ‘munsell’, ‘R6’, ‘RColorBrewer’, ‘pkgconfig’, ‘sandwich’, ‘gtable’, ‘lazyeval’, ‘reshape2’, ‘scales’, ‘tibble’, ‘viridisLite’, ‘withr’, ‘gmm’, ‘ggplot2’, ‘tmvtnorm’, ‘mvtnorm’, ‘pbapply’
# The downloaded binary packages are in
# 	/var/folders/43/w0wvg7pd2p7d651g7rz0pj8r0000gn/T//Rtmpj4ryoM/downloaded_packages
# Old packages: 'boot', 'foreign', 'KernSmooth', 'mgcv', 'nlme'

# %%
library(microbiomeDASim)
sim_dt <- mvrnorm_sim(n_control = 20, n_treat = 20, control_mean = 2, sigma = 1,
                      num_timepoints = 6, rho = 0.7, corr_str = "compound",
                      func_form = "quadratic", beta = c(0, 3, -0.5),
                      missing_pct = 0, missing_per_subject = 0,
                      dis_plot = TRUE)
# Out:
# plot without title

# %%
sim_dt <- mvrnorm_sim(n_control = 20, n_treat = 20, control_mean = 2, sigma = 1,
                      num_timepoints = 6, rho = 0.7, corr_str = "compound",
                      func_form = "quadratic",beta = c(0, 3, -0.5),
                      missing_pct = 0.2, missing_per_subject = 2,
                      miss_val = 0, dis_plot = TRUE)
# Out:
# plot without title

# %%
bug_gen <- gen_norm_microbiome(features=10, diff_abun_features=4,
                               n_control=20, n_treat=20, control_mean=2, sigma=1,
                         num_timepoints=7, rho=0.7, corr_str="compound",
                           func_form="L_down", beta=c(2, -0.5),
                           missing_pct=0.2, missing_per_subject=2,
                           miss_val=0)
# Out:
# Simulating Diff Bugs
#
# Simulating No-Diff Bugs
